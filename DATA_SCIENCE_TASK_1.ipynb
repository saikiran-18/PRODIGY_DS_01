# %% [markdown]
# <a href="https://colab.research.google.com/github/saikiran-18/PRODIGY_DS_01/blob/main/DATA_SCIENCE_TASK_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {'Age': [22, 25, 29, 34, 28, 42, 23, 26, 31, 38, 30, 35, 40, 29, 22, 33]}
df = pd.DataFrame(data)

# Create a histogram
plt.hist(df['Age'], bins=5, edgecolor='black')
plt.title('Distribution of Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {'Gender': ['Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female']}
df = pd.DataFrame(data)

# Count frequencies
gender_counts = df['Gender'].value_counts()

# Create a bar chart
plt.bar(gender_counts.index, gender_counts.values, color=['blue', 'pink'])
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()
